# %% [markdown]
# # 1994 Census bureau database
#
# ### Goal: Objective: Given some characteristics, return the probability of receiving more than \$50k
#
# [Reference: Nham, Tracy. Classifying Income from 1994 Census Data](http://cseweb.ucsd.edu/classes/sp15/cse190-c/reports/sp15/024.pdf)

# %%
import pandas as pd

# %%
df = pd.read_csv('Adult_Census_Income.csv')

# %% [markdown]
# #### A) What we have?

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# #### B) Selecting features

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# - 'fnlwgt': not useful for this work.
# - 'education.num': the feature 'education' is enough.
# - 'income': our target.

# %%
target = 'income'
black_cols = ['fnlwgt','education.num','income']
features = df.columns.tolist()
for col in black_cols:
    features.pop(features.index(col))
print(features)
# Out:
# ['age', 'workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week', 'native.country']

# %% [markdown]
# #### C) Filtering and staging values

# %% [markdown]
# - Taking a look at unique values. *Some values like numbers may not be seen below.*

# %%
cols_not_uniques = []
for col in features:
    try:
        uniqs = df[col].unique()
        print('Feature: \'{}\', total uniques {}:\n{}\n\n'.format(col,len(uniqs),"\n".join(uniqs)))
    except Exception as e:
        cols_not_uniques.append(col)
# Out:
# Feature: 'workclass', total uniques 9:
# ?
# Private
# State-gov
# Federal-gov
# Self-emp-not-inc
# Self-emp-inc
# Local-gov
# Without-pay
# Never-worked
#
#
# Feature: 'education', total uniques 16:
# HS-grad
# Some-college
# 7th-8th
# 10th
# Doctorate
# Prof-school
# Bachelors
# Masters
# 11th
# Assoc-acdm
# Assoc-voc
# 1st-4th
# 5th-6th
# 12th
# 9th
# Preschool
#
#
# Feature: 'marital.status', total uniques 7:
# Widowed
# Divorced
# Separated
# Never-married
# Married-civ-spouse
# Married-spouse-absent
# Married-AF-spouse
#
#
# Feature: 'occupation', total uniques 15:
# ?
# Exec-managerial
# Machine-op-inspct
# Prof-specialty
# Other-service
# Adm-clerical
# Craft-repair
# Transport-moving
# Handlers-cleaners
# Sales
# Farming-fishing
# Tech-support
# Protective-serv
# Armed-Forces
# Priv-house-serv
#
#
# Feature: 'relationship', total uniques 6:
# Not-in-family
# Unmarried
# Own-child
# Other-relative
# Husband
# Wife
#
#
# Feature: 'race', total uniques 5:
# White
# Black
# Asian-Pac-Islander
# Other
# Amer-Indian-Eskimo
#
#
# Feature: 'sex', total uniques 2:
# Female
# Male
#
#
# Feature: 'native.country', total uniques 42:
# United-States
# ?
# Mexico
# Greece
# Vietnam
# China
# Taiwan
# India
# Philippines
# Trinadad&Tobago
# Canada
# South
# Holand-Netherlands
# Puerto-Rico
# Poland
# Iran
# England
# Germany
# Italy
# Japan
# Hong
# Honduras
# Cuba
# Ireland
# Cambodia
# Peru
# Nicaragua
# Dominican-Republic
# Haiti
# El-Salvador
# Hungary
# Columbia
# Guatemala
# Jamaica
# Ecuador
# France
# Yugoslavia
# Scotland
# Portugal
# Laos
# Thailand
# Outlying-US(Guam-USVI-etc)

# %%
black_vals = ['?']

# %%
cols_not_uniques
# Out:
# ['age', 'capital.gain', 'capital.loss', 'hours.per.week']

# %%
df[cols_not_uniques].describe()
# Out:
#                 age  capital.gain  capital.loss  hours.per.week
# count  32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647   1077.648844     87.303830       40.437456
# std       13.640433   7385.292085    402.960219       12.347429
# min       17.000000      0.000000      0.000000        1.000000
# 25%       28.000000      0.000000      0.000000       40.000000
# 50%       37.000000      0.000000      0.000000       40.000000
# 75%       48.000000      0.000000      0.000000       45.000000
# max       90.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# - Thinking about a person's use at any time, knowing and reporting the capital gain in the year may cause an inconsistent data entry.

# %%
black_cols.extend(['capital.gain','capital.loss'])
features_num = ['age','hours.per.week']

# %%
features = df.columns.tolist()
for col in black_cols:
    features.pop(features.index(col))
print(features)
# Out:
# ['age', 'workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'hours.per.week', 'native.country']

# %%
features_cat = features
for col in features_num:
    features_cat.pop(features_cat.index(col))

# %%
print("Categorical features: {}\n\nNumerical features: {}".format(features_cat,features_num))
# Out:
# Categorical features: ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country']
#
# Numerical features: ['age', 'hours.per.week']

# %% [markdown]
# #### Creating the model
#
# - Dictionary for categorical features.

# %%
col = 'race'
# Out:
# ['White', 'Black', 'Asian-Pac-Islander', 'Other', 'Amer-Indian-Eskimo']

# %%
features_cat_dict = {}
for col in features_cat:
    tmp = df[col].unique().tolist()
    for val in black_vals:
        if val in tmp:
            tmp.pop(tmp.index(val))
    features_cat_dict[col] = tmp

# %%
features_cat_dict
# Out:
# {'workclass': ['Private',
#   'State-gov',
#   'Federal-gov',
#   'Self-emp-not-inc',
#   'Self-emp-inc',
#   'Local-gov',
#   'Without-pay',
#   'Never-worked'],
#  'education': ['HS-grad',
#   'Some-college',
#   '7th-8th',
#   '10th',
#   'Doctorate',
#   'Prof-school',
#   'Bachelors',
#   'Masters',
#   '11th',
#   'Assoc-acdm',
#   'Assoc-voc',
#   '1st-4th',
#   '5th-6th',
#   '12th',
#   '9th',
#   'Preschool'],
#  'marital.status': ['Widowed',
#   'Divorced',
#   'Separated',
#   'Never-married',
#   'Married-civ-spouse',
#   'Married-spouse-absent',
#   'Married-AF-spouse'],
#  'occupation': ['Exec-managerial',
#   'Machine-op-inspct',
#   'Prof-specialty',
#   'Other-service',
#   'Adm-clerical',
#   'Craft-repair',
#   'Transport-moving',
#   'Handlers-cleaners',
#   'Sales',
#   'Farming-fishing',
#   'Tech-support',
#   'Protective-serv',
#   'Armed-Forces',
#   'Priv-house-serv'],
#  'relationship': ['Not-in-family',
#   'Unmarried',
#   'Own-child',
#   'Other-relative',
#   'Husband',
#   'Wife'],
#  'race': ['White',
#   'Black',
#   'Asian-Pac-Islander',
#   'Other',
#   'Amer-Indian-Eskimo'],
#  'sex': ['Female', 'Male'],
#  'native.country': ['United-States',
#   'Mexico',
#   'Greece',
#   'Vietnam',
#   'China',
#   'Taiwan',
#   'India',
#   'Philippines',
#   'Trinadad&Tobago',
#   'Canada',
#   'South',
#   'Holand-Netherlands',
#   'Puerto-Rico',
#   'Poland',
#   'Iran',
#   'England',
#   'Germany',
#   'Italy',
#   'Japan',
#   'Hong',
#   'Honduras',
#   'Cuba',
#   'Ireland',
#   'Cambodia',
#   'Peru',
#   'Nicaragua',
#   'Dominican-Republic',
#   'Haiti',
#   'El-Salvador',
#   'Hungary',
#   'Columbia',
#   'Guatemala',
#   'Jamaica',
#   'Ecuador',
#   'France',
#   'Yugoslavia',
#   'Scotland',
#   'Portugal',
#   'Laos',
#   'Thailand',
#   'Outlying-US(Guam-USVI-etc)']}

# %% [markdown]
# - Get randomly sample dataset and some categories:

# %%
some_cats = ['education','age','marital.status','sex']

df_tmp = df[some_cats].sample()
df_tmp
# Out:
#       education  age      marital.status   sex
# 69  Prof-school   42  Married-civ-spouse  Male

# %%
cond = (df[some_cats[0]] == df_tmp[some_cats[0]].values.tolist()[0])
for col in some_cats[1:]:
    cond = (cond & (df[col] == df_tmp[col].values.tolist()[0]))
df_pop = df.loc[cond]
df_pop
# Out:
#        age         workclass  fnlwgt    education  education.num  \
# 69      42      Self-emp-inc  187702  Prof-school             15
# 378     42      Self-emp-inc  123838  Prof-school             15
# 537     42  Self-emp-not-inc  214242  Prof-school             15
# 562     42           Private  378384  Prof-school             15
# 845     42  Self-emp-not-inc  185129  Prof-school             15
# 1603    42  Self-emp-not-inc  201908  Prof-school             15
# 1956    42           Private  252518  Prof-school             15
# 2031    42      Self-emp-inc  277488  Prof-school             15
# 2779    42           Private   87284  Prof-school             15
# 5005    42  Self-emp-not-inc  177307  Prof-school             15
# 8443    42  Self-emp-not-inc  174216  Prof-school             15
# 10541   42         State-gov  102343  Prof-school             15
# 14680   42  Self-emp-not-inc   54202  Prof-school             15
# 19693   42         Local-gov  209752  Prof-school             15
# 23871   42           Private  171841  Prof-school             15
# 28857   42      Self-emp-inc  152071  Prof-school             15
#
#            marital.status       occupation relationship                race  \
# 69     Married-civ-spouse   Prof-specialty      Husband               White
# 378    Married-civ-spouse   Prof-specialty      Husband               White
# 537    Married-civ-spouse   Prof-specialty      Husband               White
# 562    Married-civ-spouse   Prof-specialty      Husband               White
# 845    Married-civ-spouse   Prof-specialty      Husband               White
# 1603   Married-civ-spouse   Prof-specialty      Husband               White
# 1956   Married-civ-spouse  Exec-managerial      Husband               White
# 2031   Married-civ-spouse   Prof-specialty      Husband               White
# 2779   Married-civ-spouse   Prof-specialty      Husband               White
# 5005   Married-civ-spouse  Farming-fishing      Husband               White
# 8443   Married-civ-spouse   Prof-specialty      Husband               White
# 10541  Married-civ-spouse   Prof-specialty      Husband  Asian-Pac-Islander
# 14680  Married-civ-spouse   Prof-specialty      Husband               White
# 19693  Married-civ-spouse  Exec-managerial      Husband               White
# 23871  Married-civ-spouse   Prof-specialty      Husband               White
# 28857  Married-civ-spouse   Prof-specialty      Husband               White
#
#         sex  capital.gain  capital.loss  hours.per.week native.country income
# 69     Male             0          2415              60  United-States   >50K
# 378    Male             0          1977              50  United-States   >50K
# 537    Male             0          1902              50  United-States   >50K
# 562    Male             0          1902              60  United-States   >50K
# 845    Male             0          1887              40  United-States   >50K
# 1603   Male         99999             0              50  United-States   >50K
# 1956   Male         15024             0              40  United-States   >50K
# 2031   Male         15024             0              65  United-States   >50K
# 2779   Male          7298             0              35  United-States   >50K
# 5005   Male             0             0              65  United-States   >50K
# 8443   Male             0             0              38  United-States   >50K
# 10541  Male             0             0              72          India   >50K
# 14680  Male             0             0              50  United-States   >50K
# 19693  Male             0             0              55  United-States   >50K
# 23871  Male             0             0              60  United-States  <=50K
# 28857  Male             0             0              60           Cuba   >50K

# %%
target_val = '>50K'
tg_vals = ((df_pop[target] == '>50K')*1).values.tolist()
N = len(df)
n = len(tg_vals)
p = 100*sum(tg_vals)/n
s = 100*n/N
print(df_tmp)
print("P(target) = {:.2f}%, with {:,}/{:,} ({:.4f}%) of the entire dataset.".format(p,n,N,s))
# Out:
#       education  age      marital.status   sex
# 69  Prof-school   42  Married-civ-spouse  Male
# P(target) = 93.75%, with 16/32,561 (0.0491%) of the entire dataset.

# %% [markdown]
# # Done!!
